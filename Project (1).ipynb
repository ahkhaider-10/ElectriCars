# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

root=Tk()
root.title("Health Me Up!")
root.configure(background='#EBDDE2')

#Function to predict the outcome
def predict():
    name=ent1.get()
    heightin=float(ent2.get())
    weight=int(ent3.get())
    gender=int(g.get())
    
    #Fetching the Data
    data=pd.read_csv("projectdata.csv")
    data=data.iloc[:,1:]
    
    # Spliting-out validation dataset
    array = data.values
    X = array[:,0:4]
    Y = array[:,5]
    validation_size = 0.20
    seed = 7
    X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=0.20, random_state=seed)
   
    # Test options and evaluation metric
    seed = 7
    scoring = 'accuracy'
    
    # Prediciting DataSet
    height=0.0254*heightin
    bmi=weight/(height**2)
    P=[[gender,weight,height,bmi]]
    
    # Decision Tree Model
    clf = DecisionTreeClassifier()
    clf = clf.fit(X_validation,Y_validation)
    result=str(clf.predict(P))
    messagebox.showinfo (title='Result', message="Hello !! " '%s \n As per the calculations, \n You are %s' %(name,result))
    
    
#Adding the logo
#153157624430073963
#imagelogo=PhotoImag#(file='asdfgh.png')
logo = Label(root, background='#EBDDE2')
logo.place(x=75, y=-20)
lable1 = Label(root, text="HEALTH ME UP!",background='#EBDDE2',fg="#B3446C",font = "Arial 100 bold").place(x=330, y=30)

#Adding image and text
#imageex=PhotoImage(file='asdfgh.png')
imgg = Label(root,background='#EBDDE2',height=600,width=800)
imgg.place(x=850, y=160)
lable1 = Label(root, text="Health is the ability of a biological \nsystem to acquire,convert, allocate, distribute,\n and utilize energy with maximum efficiency.\n The World Health Organization (WHO) \n defined human health as a state of \n complete physical, mental and social well-being \n and not merely the absence of disease or infirmity.",background='#EBDDE2',fg="#990000",font = "Arial 15 bold",anchor="w", borderwidth=2,relief="solid",highlightcolor="#D2691E").place(x=20, y=350)

#Inserting the labels
lable1 = Label(root, text="Name:",background='#EBDDE2',font = "Arial 35 bold",fg="#990000").place(x=550, y=250)
lable2 = Label(root, text="Gender:",background='#EBDDE2',font = "Arial 35 bold",fg="#990000").place(x=545, y=350)
lable3 = Label(root, text="Height:",background='#EBDDE2',font = "Arial 35 bold",fg="#990000").place(x=550, y=450)
lablex1 = Label(root, text="(in inches)",background='#EBDDE2',font = "Arial 15 ",fg="#990000").place(x=550, y=508)
lable4 = Label(root, text="Weight:",background='#EBDDE2',font = "Arial 35 bold",fg="#990000").place(x=550, y=570)
lableex2 = Label(root, text="(in kgs)",background='#EBDDE2',font = "Arial 15",fg="#990000").place(x=550, y=630)


#Inputting the data
large_font = ('Verdana',15)
entry1Var = StringVar(value='Large Font!')
ent1 = Entry(root,font=large_font)
ent1.place(x=750, y=270)
ent2 = Entry(root,font=large_font)
ent2.place(x=750, y=470)
ent3 = Entry(root,font=large_font)
ent3.place(x=750, y=590)

g=IntVar()
radio1=Radiobutton(root,text="Male",variable=g,value=0,background='#EBDDE2',font = "Arial 15",fg="#990000")
radio1.place(x=750, y=365)
radio2 = Radiobutton(root, text="Female", variable=g, value=1,background='#EBDDE2',font = "Arial 15",fg="#990000")
radio2.place(x=850, y=365)

button1 = Button(root, text="Predict",command=predict,width=10,background='#990000',font = "Arial 15",fg="#FDF5E6")
button1.place(x=700, y=700)
button2 = Button(root, text='Quit', command=root.destroy,width=10,background='#990000',font = "Arial 15",fg="#FDF5E6")
button2.place(x=900,y=700)



root.mainloop()
